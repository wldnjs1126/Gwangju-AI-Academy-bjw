# %%
import pandas as pd

df = pd.DataFrame({
    'study_time': [1, 2, 3, 4, 5, 6],
    'pass':      [0, 0, 0, 1, 1, 1]
})

df
# Out:
#    study_time  pass
# 0           1     0
# 1           2     0
# 2           3     0
# 3           4     1
# 4           5     1
# 5           6     1

# %%
from sklearn.linear_model import LogisticRegression

# x, y 분리
x = df[["study_time"]]
y = df["pass"]

print(x.shape)  # (6, 1) => 2차원
print(y.shape)  # (6,) => 1차원

# 모델 생성
model = LogisticRegression()

# 학습
model.fit(x,y)

print(model.coef_)  # [[1.12069525]]
print(model.intercept_)  # [-3.9223039]

# 예측
pred = model.predict(x)

print(pred)

pred = model.predict([[10]])  # 10 시간일 때
print(pred)

# 10시간, 12 시간일 때
pred = model.predict([[10],[12]])
print(pred)
# Out:
# (6, 1)
# (6,)
# [[1.12069525]]
# [-3.9223039]
# [0 0 0 1 1 1]
# [1]
# [1 1]
# c:\miniconda3\envs\env_ds\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\miniconda3\envs\env_ds\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt

# 시그모이드 함수
x = np.arange(-10,10,0.1)

y = 1/(1 + np.exp(-x))  # 시그모이드 공식

plt.plot(x,y)
plt.grid()
plt.show()

# 전체 흐름 정리
# 1. 랜덤 가중치 초기화
# 2. sigmoid로 확률 예측
# 3. 정답과 비교하여 오차 계산
# 4. 오차 기반으로 기울기 업데이트
# 5. 반복 수행
