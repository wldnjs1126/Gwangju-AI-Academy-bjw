# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
from sklearn.datasets import load_iris

# %%
from sklearn.datasets import load_iris

iris = load_iris()

# print(iris)

df = pd.DataFrame(iris.data,columns=iris.feature_names)
df['target'] = iris.target

# 엑셀 저장
df.to_excel("iris.xlsx", index=False)

df.info()

# df.columns = [
#     "sepal_length",
#     "sepal_width",
#     "petal_length",
#     "petal_width"
# ]

# df = df.rename(columns={
#     "sepal length (cm)": "꽃받침길이",
#     "sepal width (cm)": "꽃받침_너비",
#     "petal length (cm)": "꽃잎_길이",
#     "petal width (cm)": "꽃잎_너비"
# })

# sepal : 꽃받침
# petal : 꽃잎
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.pairplot(df,hue = "target")

# %%
# 머신러닝

# 2. x(입력), y(정답) 분리

x = df.drop("target",axis=1)  # df 자체에서 target이 사라지는게 아닌 target을 뺀 데이터 값이 x로 복사되는 것
y = df["target"]

# ⁠3. 학습용 / 테스트용 분리
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# 위 split에서 test_size = 0.2는 전체의 20%를 test로 하라는 의미
# 학습 : 120개
# 테스트 : 30개

# %%
# 4. 로지스틱 회귀 모델 생성

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred = model.predict(x_test)
print(pred)
# Out:
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]

# %%
# 5. 평가 지표

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

print("Accuracy:", accuracy_score(y_test, pred))
print("Precision:", precision_score(y_test, pred, average='macro'))
print("Recall:", recall_score(y_test, pred, average='macro'))
print("F1:", f1_score(y_test, pred, average='macro'))

print("Confusion Matrix:\n", confusion_matrix(y_test, pred))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1: 1.0
# Confusion Matrix:
#  [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %%
# TP (True Positive) : 합격인데 합격이라고 맞춤
# FP (False Positive) : 불합격인데 합격이라고 잘못 예측
# TN (True Negative) : 불합격인데 불합격이라고 맞춤
# FN (False Negative) : 합격인데 불합격이라고 잘못 예측

# True : 맞춤, False : 틀림
# Positive : 합격, Negative : 불합격

# 정확도 (Accuracy) = TP, TN 상관없이 맞춘 것
# 정밀도 (precision) = TP 만
