# %%
# 랜덤 포레스트 (피쳐 중요도)
# 배깅은 행만 랜덤이었다고 하면, 랜덤 포레스트는 행과 열 , 컬럼의 개수까지 다 랜덤

import pandas as pd

from sklearn.ensemble import RandomForestClassifier

df = pd.DataFrame({
    "study":[1,2,3,4,5,6,7,8],
    "sleep":[8,7,7,6,6,5,5,4],
    "homework":[1,2,3,4,5,6,7,8],
    "pass":[0,0,0,0,1,1,1,1]
})

x = df[["study","sleep","homework"]]
y = df["pass"]

# 랜덤 포레스트 적용
model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# 학습
model.fit(x,y)

# 예측
pred = model.predict([[9,5,5]])

print(pred)
# Out:
# [1]
# c:\miniconda3\envs\env_ds\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
