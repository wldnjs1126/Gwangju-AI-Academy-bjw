# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 🔥 1. 데이터 (작고 noisy하게)
np.random.seed(42)

X = np.linspace(0, 1, 50) # 0부터 1까지를 50개로 균등하게 나눔 #[0.0, 0.0204, 0.0408, ..., 1.0]
y = 3 * X + np.random.normal(0, 0.1, 50)  # noise 추가 = y = 직선 + 약간의 흔들림

X = X.reshape(-1, 1)
print(X.shape)
print(X)


# 🔥 2. 모델 (과하게 크게 만들어서 overfitting 유도)
model = Sequential([
    Dense(128, activation='relu', input_shape=(1,)),
    Dense(128, activation='relu'),
    Dense(128, activation='relu'),
    Dense(1)
])

model.compile(
    optimizer='adam',
    loss='mse'
)

# val_loss를 계속 관찰
# 최고 성능에서 부터
# 5 epoch 동안 기다림
# 개선되지 않으면 학습을 중단 
# => 중단의 의미 : 최적의 파라미터가 되버림 
# => 중단 하는 이유 : 과적합 방지, 시간 낭비 방지

# EarlyStopping을 쓰는 이유 : 과적합 해결

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True  # 이 코드는 학습이 중단되면 가장 성능이 좋았던 시점의 가중치로 되돌림
)

# 체크 포인트 : 최고 성능 모델을 저장하는 역할
checkpoint = ModelCheckpoint(
    "best_model.keras",        # 저장 파일
    monitor='val_loss',        # 기준
    save_best_only=True,       # 최고 성능만 저장
    mode='min',                # loss는 최소값 기준
    verbose=1
)

# 학습
history = model.fit(
    X, y,
    epochs=500,
    validation_split=0.3,
    callbacks=[early_stop,checkpoint],
    verbose=1
)
# Out:
# (50, 1)
# [[0.        ]
#  [0.02040816]
#  [0.04081633]
#  [0.06122449]
#  [0.08163265]
#  [0.10204082]
#  [0.12244898]
#  [0.14285714]
#  [0.16326531]
#  [0.18367347]
#  [0.20408163]
#  [0.2244898 ]
#  [0.24489796]
#  [0.26530612]
#  [0.28571429]
#  [0.30612245]
#  [0.32653061]
#  [0.34693878]
#  [0.36734694]
#  [0.3877551 ]
#  [0.40816327]
#  [0.42857143]
#  [0.44897959]
#  [0.46938776]
#  [0.48979592]
#  [0.51020408]
#  [0.53061224]
#  [0.55102041]
#  [0.57142857]
#  [0.59183673]
#  [0.6122449 ]
#  [0.63265306]
#  [0.65306122]
#  [0.67346939]
#  [0.69387755]
#  [0.71428571]
#  [0.73469388]
#  [0.75510204]
#  [0.7755102 ]
#  [0.79591837]
#  [0.81632653]
#  [0.83673469]
#  [0.85714286]
#  [0.87755102]
#  [0.89795918]
#  [0.91836735]
#  [0.93877551]
#  [0.95918367]
#  [0.97959184]
#  [1.        ]]
# Epoch 1/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 615ms/step - loss: 1.3232
# Epoch 1: val_loss improved from None to 5.65682, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 951ms/step - loss: 1.3628 - val_loss: 5.6568
# Epoch 2/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.3223
# Epoch 2: val_loss improved from 5.65682 to 5.18998, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.2303 - val_loss: 5.1900
# Epoch 3/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0418
# Epoch 3: val_loss improved from 5.18998 to 4.71726, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 1.1073 - val_loss: 4.7173
# Epoch 4/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.9556
# Epoch 4: val_loss improved from 4.71726 to 4.17188, saving model to best_model.keras
#
# Epoch 4: finished saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.9879 - val_loss: 4.1719
# Epoch 5/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.8704
# Epoch 5: val_loss improved from 4.17188 to 3.58081, saving model to best_model.keras
#
# Epoch 5: finished saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.8532 - val_loss: 3.5808
# Epoch 6/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.6873
# Epoch 6: val_loss improved from 3.58081 to 2.94167, saving model to best_model.keras
#
# Epoch 6: finished saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.7031 - val_loss: 2.9417
# Epoch 7/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5983
# Epoch 7: val_loss improved from 2.94167 to 2.30035, saving model to best_model.keras
#
# Epoch 7: finished saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.5561 - val_loss: 2.3003
# Epoch 8/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4292
# Epoch 8: val_loss improved from 2.30035 to 1.69124, saving model to best_model.keras
#
# Epoch 8: finished saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.4076 - val_loss: 1.6912
# Epoch 9/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2662
# Epoch 9: val_loss improved from 1.69124 to 1.11594, saving model to best_model.keras
#
# Epoch 9: finished saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.2713 - val_loss: 1.1159
# Epoch 10/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1645
# Epoch 10: val_loss improved from 1.11594 to 0.61254, saving model to best_model.keras
#
# Epoch 10: finished saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.1616 - val_loss: 0.6125
# Epoch 11/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0953
# Epoch 11: val_loss improved from 0.61254 to 0.26271, saving model to best_model.keras
#
# Epoch 11: finished saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0925 - val_loss: 0.2627
# Epoch 12/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0587
# Epoch 12: val_loss improved from 0.26271 to 0.07858, saving model to best_model.keras
#
# Epoch 12: finished saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0637 - val_loss: 0.0786
# Epoch 13/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0815
# Epoch 13: val_loss improved from 0.07858 to 0.01964, saving model to best_model.keras
#
# Epoch 13: finished saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0877 - val_loss: 0.0196
# Epoch 14/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1208
# Epoch 14: val_loss improved from 0.01964 to 0.01362, saving model to best_model.keras
#
# Epoch 14: finished saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.1220 - val_loss: 0.0136
# Epoch 15/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1286
# Epoch 15: val_loss did not improve from 0.01362
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1356 - val_loss: 0.0144
# Epoch 16/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1221
# Epoch 16: val_loss did not improve from 0.01362
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1198 - val_loss: 0.0284
# Epoch 17/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0959
# Epoch 17: val_loss did not improve from 0.01362
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0904 - val_loss: 0.0688
# Epoch 18/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0722
# Epoch 18: val_loss did not improve from 0.01362
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0668 - val_loss: 0.1325
# Epoch 19/500
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0476
# Epoch 19: val_loss did not improve from 0.01362
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0523 - val_loss: 0.2080

# %%
from tensorflow.keras.models import load_model

best_model = load_model("best_model.keras")

print("모델 로드 완료")
# Out:
# 모델 로드 완료

# %%
# 예측

X_new = np.array([
    [0.2],
    [0.5],
    [0.8]
])

pred = best_model.predict(X_new)

print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# [[1.0107574]
#  [1.6812994]
#  [2.3523564]]

# %%
# 시각화 

import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')

plt.title('Loss vs Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# val_loss 그래프가 위로 올라가는 순간 과적합이 발생한거임 => 계속해서 오차가 커지는 것

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import KFold

# =========================
# 1. 데이터
# =========================
np.random.seed(42)

X = np.linspace(0, 1, 100)
y = 3 * X + np.random.normal(0, 0.1, 100)

X = X.reshape(-1, 1)

# =========================
# 2. K-Fold 설정
# =========================
kf = KFold(n_splits=5, shuffle=True, random_state=42)

fold = 1
scores = []

# =========================
# 3. K-Fold 반복
# =========================
for train_idx, val_idx in kf.split(X):

    print(f"\n🔥 Fold {fold}")

    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

# =========================
# 4. 모델 (매 fold마다 새로 생성)
# =========================
    model = Sequential([
        Dense(64, activation='relu', input_shape=(1,)),
        Dense(64, activation='relu'),
        Dense(1)
    ])

    model.compile(
        optimizer='adam',
        loss='mse'
    )

# =========================
# 5. EarlyStopping
# =========================
    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )

# =========================
# 6. ModelCheckpoint (fold마다 파일 분리)
# =========================
    checkpoint = ModelCheckpoint(
        f"best_model_fold_{fold}.keras",
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        verbose=0
    )

# =========================
# 7. 학습
# =========================
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=200,
        callbacks=[early_stop, checkpoint],
        verbose=0
    )

# =========================
# 8. 평가
# =========================
    loss = model.evaluate(X_val, y_val, verbose=0)
    scores.append(loss)

    print(f"Fold {fold} Loss: {loss}")

    fold += 1

# =========================
# 9. 최종 결과
# =========================
print("\n🔥 평균 Loss:", np.mean(scores))
# Out:
# 🔥 Fold 1
# Fold 1 Loss: 0.006425949744880199
#
# 🔥 Fold 2
# Fold 2 Loss: 0.004687338136136532
#
# 🔥 Fold 3
# Fold 3 Loss: 0.008804227225482464
#
# 🔥 Fold 4
# Fold 4 Loss: 0.005538559518754482
#
# 🔥 Fold 5
# Fold 5 Loss: 0.013682435266673565
#
# 🔥 평균 Loss: 0.007827701978385448
