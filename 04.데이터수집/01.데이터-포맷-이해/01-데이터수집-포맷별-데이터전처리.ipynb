# %%
# .csv 파일 이해

# %%
# %%writefile sample1.csv
# c1, c2, c3
# 1, 1.11, one
# 2, 2.22, two
# 3, 3.33, three
# Out:
# Overwriting sample1.csv

# %%
# csv를 판다스로 읽어 들이기
import pandas as pd

df_sample = pd.read_csv("sample1.csv")
df_sample
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   c1      3 non-null      int64
#  1    c2     3 non-null      float64
#  2    c3     3 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 204.0+ bytes

# %%
# JSON 특징
# 자바스크립트에사 사용하는 데이터 표현방식을 그대로 사용함 (파이썬으로 보면 딕셔너리와 같음)
# 인터넷 네트워크로 데이터를 전송할 떄 사실상 표준으로 자리잡은 데이터 전송 포맷
# 파일 크기는 csv나 xlsx 보다 훨씬 크지만 값을 표현하는 방식이 굉장히 유연함

# %%
# %%writefile sample.json
#
# [
#     {
#       "id": "A001",
#       "city": "Tokyo",
#       "country": "Japan",
#     },
#     {
#       "id": "B012",
#       "city": "Jerusalem",
#       "country": "Isreal",
#     },
#     {
#       "id": "C123",
#       "city": "Busan",
#       "country": "South Korea",
#     }
# ]
# # 리스트 안에 딕셔너리가 있는 형태
# Out:
# Overwriting sample.json

# %%
# JSON은 JavaScript Object Notation의 약자로,
# 데이터를 구조화하여 저장하거나 전송할 때 사용하는 포맷
# 주로 웹에서 클라이언트와 서버 간 데이터 교환에 사용

# 가볍고 텍스트 기반이라 사람이 읽고 쓰기 쉬움
# 대부분의 프로그래밍 언어에서 쉽게 읽고 생성 가능
# 키-값 쌍(key-value pair)으로 구성된 데이터 구조 사용


df_json = pd.read_json("sample.json")

df_json.info()
df_json.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_34877/2613105969.py in <cell line: 0>()
#       8
#       9
# ---> 10 df_json = pd.read_json("sample.json")
#      11
#      12 df_json.info()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813         return json_reader
#     814     else:
# --> 815         return json_reader.read()
#     816
#     817
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in read(self)
#    1023                         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024                 else:
# -> 1025                     obj = self._get_object_parser(self.data)
#    1026                 if self.dtype_backend is not lib.no_default:
#    1027                     return obj.convert_dtypes(
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#    1049         obj = None
#    1050         if typ == "frame":
# -> 1051             obj = FrameParser(json, **kwargs).parse()
#    1052
#    1053         if typ == "series" or obj is None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in parse(self)
#    1185     @final
#    1186     def parse(self):
# -> 1187         self._parse()
#    1188
#    1189         if self.obj is None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in _parse(self)
#    1401         if orient == "columns":
#    1402             self.obj = DataFrame(
# -> 1403                 ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1404             )
#    1405         elif orient == "split":
#
# ValueError: Trailing data

# %%
# 웹에서 json 가져오기
url = "https://jsonplaceholder.typicode.com/users"
df_json = pd.read_json(url)

df_json.head()
# Out:
#    id              name   username                      email  \
# 0   1     Leanne Graham       Bret          Sincere@april.biz
# 1   2      Ervin Howell  Antonette          Shanna@melissa.tv
# 2   3  Clementine Bauch   Samantha         Nathan@yesenia.net
# 3   4  Patricia Lebsack   Karianne  Julianne.OConner@kory.org
# 4   5  Chelsey Dietrich     Kamren   Lucio_Hettinger@annie.ca
#
#                                              address                  phone  \
# 0  {'street': 'Kulas Light', 'suite': 'Apt. 556',...  1-770-736-8031 x56442
# 1  {'street': 'Victor Plains', 'suite': 'Suite 87...    010-692-6593 x09125
# 2  {'street': 'Douglas Extension', 'suite': 'Suit...         1-463-123-4447
# 3  {'street': 'Hoeger Mall', 'suite': 'Apt. 692',...      493-170-9623 x156
# 4  {'street': 'Skiles Walks', 'suite': 'Suite 351...          (254)954-1289
#
#          website                                            company
# 0  hildegard.org  {'name': 'Romaguera-Crona', 'catchPhrase': 'Mu...
# 1  anastasia.net  {'name': 'Deckow-Crist', 'catchPhrase': 'Proac...
# 2    ramiro.info  {'name': 'Romaguera-Jacobson', 'catchPhrase': ...
# 3       kale.biz  {'name': 'Robel-Corkery', 'catchPhrase': 'Mult...
# 4   demarco.info  {'name': 'Keebler LLC', 'catchPhrase': 'User-c...

# %%
# 데이타 프레임을 json 으로 변환 및 저장
import pandas as pd

data = {
        '이름': ['John', 'Doe', 'Jane'],
        '나이': [30, 25, 28],
        '성별': ['남성', '남성', '여성']
        }

df = pd.DataFrame(data)

print(df.head())

# 데이타프레임을 json 으로 바꿈
json_data = df.to_json(orient="records",indent=4)
print(json_data)

# 데이타 프레임을 JSON 파일로 바로 저장
# 각 행을 JSON 객체로 변환 (리스트 형태)
# df.to_json('행기준.json', orient="records",force_ascii=False,indent=4)
# df.to_json('열기준.json', orient="columns",force_ascii=False,indent=4)
# Out:
#      이름  나이  성별
# 0  John  30  남성
# 1   Doe  25  남성
# 2  Jane  28  여성
# [
#     {
#         "\uc774\ub984":"John",
#         "\ub098\uc774":30,
#         "\uc131\ubcc4":"\ub0a8\uc131"
#     },
#     {
#         "\uc774\ub984":"Doe",
#         "\ub098\uc774":25,
#         "\uc131\ubcc4":"\ub0a8\uc131"
#     },
#     {
#         "\uc774\ub984":"Jane",
#         "\ub098\uc774":28,
#         "\uc131\ubcc4":"\uc5ec\uc131"
#     }
# ]

# %%
# xml 배경
# extend markup language
# 요즘에는 가격때문에 xml에서 필요한 것들을 싹 빼서 json으로 변환시켜서 사용함
# json은 딕셔너리처럼 키 : 벨류 값만 적어주면 되기에 코드가 짧아짐

# %%
# %%writefile test.xml
# <?xml version="1.0" encoding="utf-8"?>
# <world name = "주소록과 네이버 API 서비스키">
#     <people name='김민국' >
#         <age>15</age>
#         <tall>183cm</tall>
#         <add>서울시 서대문구</add>
#     </people>
#     <people name='박한솔' >
#         <age>30</age>
#         <tall>175cm</tall>
#         <add>서울시 용산구</add>
#     </people>
#     <naver_api>
#         <client_id>JXRlq56Db1L0PA</client_id>
#         <client_secret>hwiniqqkgvH</client_secret>
#     </naver_api>
# </world>
# Out:
# Overwriting test.xml

# %%
# 부모, 자식 관계의 형태를 보이는 코드이기에 형식적인 코드로 변환을 하면 우리가 원하는 것이외에도 정리가 되어 보기 불편함
# 출력된 것의 마지막을 보면 naver api에 대한 것들이 나와있음
import pandas as pd

df = pd.read_xml("test.xml")

print(df)
# Out:
#    name   age   tall       add       client_id client_secret
# 0   김민국  15.0  183cm  서울시 서대문구            None          None
# 1   박한솔  30.0  175cm   서울시 용산구            None          None
# 2  None   NaN   None      None  JXRlq56Db1L0PA   hwiniqqkgvH

# %%
import xml.etree.ElementTree as ET

tree = ET.parse("test.xml")
root = tree.getroot()
print(root.tag)
print(root.get('name'))

for child in root:
    print(child.tag, child.attrib)

for age in root.iter("age"):
    print(age.text)
# Out:
# world
# 주소록과 네이버 API 서비스키
# people {'name': '김민국'}
# people {'name': '박한솔'}
# naver_api {}
# 15
# 30

# %%
# 엑셀 다루기

import pandas as pd

data = {
    "이름": ["홍길동", "김영희", "이철수"],
    "나이": [30, 25, 28],
    "직업": ["개발자", "디자이너", "기획자"]
}

df = pd.DataFrame(data)

df

df.to_excel('데이터.xlsx', index=False)
