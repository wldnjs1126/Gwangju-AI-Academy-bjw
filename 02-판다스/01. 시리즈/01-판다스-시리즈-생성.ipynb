# %%
# 대부분의 데이터는 시리즈나 표 형태로 나타낼 수 있음
# 행의 이름 - 인덱스, 열의 이름 - 컬럼 , 안의 내용 - 넘파이 
# 시리즈 - 1차원, 테이블 - 2차원 => 3차원은 다루지 못함

# 차원 배열 구조 - Series : 1차원 배열
# 행번호 + 인덱스 + 데이타 3개의 변수를 기본적으로 가지고 있음
# 인덱스(index) 사용 가능 - 인덱싱/슬라이싱
# 데이터 타입을 가짐 (dtype)

# 모든 데이터는 판다스를 통한다.

# 시리즈는 column이 없고, index만 있음

# 시리즈 
# 2차원은 아니고 1차원 표라고 부름

# 판다스 = 시리즈 객체 + 데이터프레임 객체
# 1차원, 2차원은 판다스를 사용하고, 3차원 이상은 넘파이를 사용

# %%
import pandas as pd
import numpy as np

arr = np.arange(100,105)
print(arr)

series = pd.Series(arr)
print(type(series))
print(series)
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# dtype: int64 => 시리즈 객체는 이렇게 정리되어서 나옴

print(dir(series))
# Out:
# [100 101 102 103 104]
# <class 'pandas.core.series.Series'>
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# dtype: int64
# ...

# %%
arr = np.arange(100,105)
print(arr)

series = pd.Series(arr,dtype='float')
print(type(series))
print(series)
print(dir(series))
# Out:
# [100 101 102 103 104]
# <class 'pandas.core.series.Series'>
# 0    100.0
# 1    101.0
# 2    102.0
# 3    103.0
# 4    104.0
# dtype: float64
# ...

# %%
# arr 자리에 리스트도 가능, 튜플도 가능, 문자열도 가능

series = pd.Series(['사과','딸기'])
print(type(series))
print(series)
print(dir(series))
# dtype: object, object는 객체라는 의미로 문자열이나 여러 종류가 섞인 데이터 타입
# Out:
# <class 'pandas.core.series.Series'>
# 0    사과
# 1    딸기
# dtype: object
# ...

# %%
series = pd.Series(['사과',91,3.14])
print(type(series))
print(series)
print(dir(series))
# Out:
# <class 'pandas.core.series.Series'>
# 0      사과
# 1      91
# 2    3.14
# dtype: object
# ...

# %%
data = {'a' : 100, 'b' :200}

series = pd.Series(data)
print(series)
# index = 라벨 = 행 이름
# Out:
# a    100
# b    200
# dtype: int64
