# %%
# !pip install langchain langchain-openai langchain-anthropic langgraph
from openai import OpenAI
# Out:
#   WARNING: The script websockets.exe is installed in 'C:\Users\user\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tqdm.exe is installed in 'C:\Users\user\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script distro.exe is installed in 'C:\Users\user\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain
#   Downloading langchain-1.3.11-py3-none-any.whl.metadata (6.0 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-1.3.3-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-anthropic
#   Downloading langchain_anthropic-1.4.8-py3-none-any.whl.metadata (3.5 kB)
# Collecting langgraph
#   Downloading langgraph-1.2.7-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core<2.0.0,>=1.4.7 (from langchain)
#   Downloading langchain_core-1.4.8-py3-none-any.whl.metadata (4.7 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph)
#   Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.5.0,>=0.4.2 (from langgraph)
#   Downloading langgraph_sdk-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph)
#   Downloading xxhash-3.8.0-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.17 (from langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading langchain_protocol-0.0.18-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading langsmith-0.9.5-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: packaging>=23.2.0 in C:\miniconda3\envs\env_ds\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\miniconda3\envs\env_ds\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\miniconda3\envs\env_ds\Lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading uuid_utils-0.16.2-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: jsonpointer>=1.9 in C:\miniconda3\envs\env_ds\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain) (3.1.1)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph)
#   Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in C:\miniconda3\envs\env_ds\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph)
#   Downloading orjson-3.11.9-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Collecting websockets<16,>=14 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph)
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: anyio>=3.5.0 in C:\miniconda3\envs\env_ds\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (4.14.0)
# Collecting distro>=1.7.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in C:\miniconda3\envs\env_ds\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (2.34.2)
# Collecting sniffio>=1.1 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: certifi in C:\miniconda3\envs\env_ds\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\miniconda3\envs\env_ds\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in C:\miniconda3\envs\env_ds\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\miniconda3\envs\env_ds\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.46.4-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting openai<3.0.0,>=2.26.0 (from langchain-openai)
#   Downloading openai-2.44.0-py3-none-any.whl.metadata (34 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.13.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Downloading jiter-0.16.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Collecting tqdm>4 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Downloading tqdm-4.68.3-py3-none-any.whl.metadata (57 kB)
# Collecting regex (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2026.6.28-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting anthropic<1.0.0,>=0.96.0 (from langchain-anthropic)
#   Downloading anthropic-0.115.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting docstring-parser<1,>=0.15 (from anthropic<1.0.0,>=0.96.0->langchain-anthropic)
#   Downloading docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\miniconda3\envs\env_ds\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\miniconda3\envs\env_ds\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (2.7.0)
# Requirement already satisfied: colorama in C:\Users\user\AppData\Roaming\Python\Python312\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)
# Downloading langchain-1.3.11-py3-none-any.whl (133 kB)
# Downloading langgraph-1.2.7-py3-none-any.whl (246 kB)
# Downloading langchain_core-1.4.8-py3-none-any.whl (557 kB)
#    ---------------------------------------- 0.0/557.4 kB ? eta -:--:--
#    ---------------------------------------- 557.4/557.4 kB 6.4 MB/s  0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl (56 kB)
# Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Downloading langgraph_sdk-0.4.2-py3-none-any.whl (160 kB)
# Downloading langsmith-0.9.5-py3-none-any.whl (603 kB)
#    ---------------------------------------- 0.0/603.9 kB ? eta -:--:--
#    ---------------------------------------- 603.9/603.9 kB 5.5 MB/s  0:00:00
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 12.8 MB/s  0:00:00
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.16.2-cp312-cp312-win_amd64.whl (173 kB)
# Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Downloading langchain_openai-1.3.3-py3-none-any.whl (120 kB)
# Downloading openai-2.44.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 14.2 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.16.0-cp312-cp312-win_amd64.whl (196 kB)
# Downloading tiktoken-0.13.0-cp312-cp312-win_amd64.whl (874 kB)
#    ---------------------------------------- 0.0/874.7 kB ? eta -:--:--
#    ---------------------------------------- 874.7/874.7 kB 19.8 MB/s  0:00:00
# Downloading langchain_anthropic-1.4.8-py3-none-any.whl (52 kB)
# Downloading anthropic-0.115.1-py3-none-any.whl (957 kB)
#    ---------------------------------------- 0.0/957.0 kB ? eta -:--:--
#    ---------------------------------------- 957.0/957.0 kB 14.8 MB/s  0:00:00
# Downloading docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading langchain_protocol-0.0.18-py3-none-any.whl (7.2 kB)
# Downloading orjson-3.11.9-cp312-cp312-win_amd64.whl (127 kB)
# Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl (117 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading tqdm-4.68.3-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.8.0-cp312-cp312-win_amd64.whl (32 kB)
# Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl (506 kB)
# Downloading regex-2026.6.28-cp312-cp312-win_amd64.whl (277 kB)
# Installing collected packages: zstandard, xxhash, websockets, uuid-utils, typing-inspection, tqdm, tenacity, sniffio, regex, pydantic-core, ormsgpack, orjson, langchain-protocol, jsonpatch, jiter, docstring-parser, distro, annotated-types, tiktoken, requests-toolbelt, pydantic, openai, langsmith, anthropic, langchain-core, langgraph-sdk, langgraph-checkpoint, langchain-openai, langchain-anthropic, langgraph-prebuilt, langgraph, langchain
#
#    -- -------------------------------------  2/32 [websockets]
#    --- ------------------------------------  3/32 [uuid-utils]
#    ------ ---------------------------------  5/32 [tqdm]
#    ---------- -----------------------------  8/32 [regex]
#    ------------ --------------------------- 10/32 [ormsgpack]
#    -------------------- ------------------- 16/32 [distro]
#    ----------------------- ---------------- 19/32 [requests-toolbelt]
#    ------------------------- -------------- 20/32 [pydantic]
#    ------------------------- -------------- 20/32 [pydantic]
#    ------------------------- -------------- 20/32 [pydantic]
#    ------------------------- -------------- 20/32 [pydantic]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    -------------------------- ------------- 21/32 [openai]
#    --------------------------- ------------ 22/32 [langsmith]
#    --------------------------- ------------ 22/32 [langsmith]
#    --------------------------- ------------ 22/32 [langsmith]
#    --------------------------- ------------ 22/32 [langsmith]
#    --------------------------- ------------ 22/32 [langsmith]
#    --------------------------- ------------ 22/32 [langsmith]
#    --------------------------- ------------ 22/32 [langsmith]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ---------------------------- ----------- 23/32 [anthropic]
#    ------------------------------ --------- 24/32 [langchain-core]
#    ------------------------------ --------- 24/32 [langchain-core]
#    ------------------------------ --------- 24/32 [langchain-core]
#    ------------------------------ --------- 24/32 [langchain-core]
#    ------------------------------ --------- 24/32 [langchain-core]
#    ------------------------------- -------- 25/32 [langgraph-sdk]
#    -------------------------------- ------- 26/32 [langgraph-checkpoint]
#    --------------------------------- ------ 27/32 [langchain-openai]
#    ------------------------------------- -- 30/32 [langgraph]
#    ------------------------------------- -- 30/32 [langgraph]
#    ------------------------------------- -- 30/32 [langgraph]
#    -------------------------------------- - 31/32 [langchain]
#    ---------------------------------------- 32/32 [langchain]
#
# Successfully installed annotated-types-0.7.0 anthropic-0.115.1 distro-1.9.0 docstring-parser-0.18.0 jiter-0.16.0 jsonpatch-1.33 langchain-1.3.11 langchain-anthropic-1.4.8 langchain-core-1.4.8 langchain-openai-1.3.3 langchain-protocol-0.0.18 langgraph-1.2.7 langgraph-checkpoint-4.1.1 langgraph-prebuilt-1.1.0 langgraph-sdk-0.4.2 langsmith-0.9.5 openai-2.44.0 orjson-3.11.9 ormsgpack-1.12.2 pydantic-2.13.4 pydantic-core-2.46.4 regex-2026.6.28 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.4 tiktoken-0.13.0 tqdm-4.68.3 typing-inspection-0.4.2 uuid-utils-0.16.2 websockets-15.0.1 xxhash-3.8.0 zstandard-0.25.0

# %%
api_key = "sk-"
client = OpenAI(api_key=api_key)

reponse = client.responses.create(
    model = "gpt-4o-mini",
    input="2022년 월드컵 우승팀은 어디야?"
)

print(reponse.output_text)
# Out:
# 2022년 FIFA 월드컵 우승팀은 아르헨티나입니다. 아르헨티나는 결승에서 프랑스를 상대로 승리하여 36년 만에 월드컵 트로피를 다시 차지했습니다.

# %%
from openai import OpenAI

api_key = 'sk-'	

client = OpenAI(api_key=api_key)

from openai import OpenAI

client = OpenAI(
    api_key=api_key
)

response = client.responses.create(
    model="gpt-4o-mini",
    input="2022년 월드컵 우승팀은 어디야?"
)

print(response.output_text)
# Out:
# 2022년 월드컵 우승 팀은 아르헨티나입니다. 아르헨티나는 결승에서 프랑스를 이기고 우승을 차지했습니다.
